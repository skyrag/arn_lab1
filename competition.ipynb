# %% [markdown]
# <a href="https://colab.research.google.com/github/skyrag/arn_lab1/blob/main/competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Competition : Test**

# %%
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as pl
import numpy as np

from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from keras import layers

mice_eeg1 = pd.read_csv('EEG_mouse_data_1.csv')
mice_eeg2 = pd.read_csv('EEG_mouse_data_2.csv')
mice_eeg = pd.concat([mice_eeg1, mice_eeg2])
mice_eeg = np.array(mice_eeg)

scaler = StandardScaler()

mice_eeg_input = mice_eeg[:, 1:26:]
mice_eeg_input = mice_eeg_input.astype('float32')
mice_eeg_output = mice_eeg[:, 0:1:]

# At first, we only want an awake state and an asleep state
mice_eeg_output[mice_eeg_output == 'w'] = 0
mice_eeg_output[mice_eeg_output == 'n'] = 1
mice_eeg_output[mice_eeg_output == 'r'] = 2
mice_eeg_output = mice_eeg_output.astype('float32')

#3-Fold
pl.clf()
keras.utils.set_random_seed(123)
kfold = KFold(n_splits=3, shuffle=True)
for i, (train_index, test_index) in enumerate(kfold.split(mice_eeg)):
    print(f"Fold ", i)
    print('train: %s', (mice_eeg_input[train_index]))
    print('test: %s', (mice_eeg_input[test_index]))
# Out:
# Fold  0
# train: %s [[9.12315045e-06 1.36561475e-05 1.28317988e-05 ... 1.31561694e-06
#   1.88253500e-06 3.55532109e-07]
#  [1.08095901e-05 7.67086240e-05 3.43861975e-05 ... 3.17965402e-07
#   3.83331752e-07 2.46632396e-07]
#  [3.21241259e-06 3.08873277e-05 4.41908232e-05 ... 2.85465632e-07
#   9.18769501e-07 5.57924125e-07]
#  ...
#  [1.62138767e-05 2.84640701e-05 3.14285789e-05 ... 1.22219163e-07
#   1.27733472e-07 2.25666255e-07]
#  [1.28606980e-05 1.36000399e-05 1.97660538e-05 ... 8.17007844e-07
#   6.63020728e-07 9.61558953e-07]
#  [3.54205235e-06 5.87464774e-06 1.07878577e-05 ... 3.68524252e-06
#   7.30184752e-07 1.33459343e-06]]
# test: %s [[9.7950606e-06 9.5739406e-06 1.1024227e-05 ... 8.9586655e-07
#   2.8650393e-07 8.2809350e-07]
#  [1.1652465e-05 3.1402640e-05 2.3917843e-05 ... 9.1464625e-07
#   4.1769374e-07 6.3444008e-07]
#  [8.1991730e-06 2.3801601e-06 2.5496408e-06 ... 2.7289238e-07
#   6.2229549e-07 4.5304515e-07]
#  ...
#  [2.5190859e-05 7.7235709e-06 1.2473907e-05 ... 3.0806791e-07
#   4.0739198e-07 4.5185126e-07]
#  [1.9573354e-05 1.4259240e-05 1.8272962e-05 ... 6.2572121e-07
#   3.7814473e-07 3.0468598e-07]
#  [1.4239453e-05 1.5536778e-05 1.0429142e-05 ... 6.3990342e-07
#   6.7461701e-07 8.2815177e-08]]
# Fold  1
# train: %s [[9.12315045e-06 1.36561475e-05 1.28317988e-05 ... 1.31561694e-06
#   1.88253500e-06 3.55532109e-07]
#  [9.79506058e-06 9.57394059e-06 1.10242272e-05 ... 8.95866549e-07
#   2.86503933e-07 8.28093505e-07]
#  [9.68985296e-06 1.10363299e-05 1.17873669e-05 ... 9.67869937e-07
#   6.37402536e-07 8.64302763e-07]
#  ...
#  [1.66734808e-05 3.84007508e-05 1.45951080e-05 ... 7.68478742e-07
#   1.13163526e-06 1.08088955e-06]
#  [1.62138767e-05 2.84640701e-05 3.14285789e-05 ... 1.22219163e-07
#   1.27733472e-07 2.25666255e-07]
#  [3.54205235e-06 5.87464774e-06 1.07878577e-05 ... 3.68524252e-06
#   7.30184752e-07 1.33459343e-06]]
# test: %s [[1.0809590e-05 7.6708624e-05 3.4386198e-05 ... 3.1796540e-07
#   3.8333175e-07 2.4663240e-07]
#  [3.2124126e-06 3.0887328e-05 4.4190823e-05 ... 2.8546563e-07
#   9.1876950e-07 5.5792412e-07]
#  [1.4855380e-05 1.2353143e-05 1.2741492e-05 ... 1.2508331e-06
#   5.6701799e-07 4.4376452e-07]
#  ...
#  [1.4911315e-06 1.5170375e-05 1.0504380e-05 ... 8.3103049e-07
#   4.0479628e-07 1.5521002e-07]
#  [2.4599271e-05 7.2302678e-06 6.7786023e-06 ... 1.1557217e-06
#   4.6743349e-07 4.7105917e-07]
#  [1.2860698e-05 1.3600040e-05 1.9766054e-05 ... 8.1700784e-07
#   6.6302073e-07 9.6155895e-07]]
# Fold  2
# train: %s [[9.7950606e-06 9.5739406e-06 1.1024227e-05 ... 8.9586655e-07
#   2.8650393e-07 8.2809350e-07]
#  [1.0809590e-05 7.6708624e-05 3.4386198e-05 ... 3.1796540e-07
#   3.8333175e-07 2.4663240e-07]
#  [3.2124126e-06 3.0887328e-05 4.4190823e-05 ... 2.8546563e-07
#   9.1876950e-07 5.5792412e-07]
#  ...
#  [1.4239453e-05 1.5536778e-05 1.0429142e-05 ... 6.3990342e-07
#   6.7461701e-07 8.2815177e-08]
#  [2.4599271e-05 7.2302678e-06 6.7786023e-06 ... 1.1557217e-06
#   4.6743349e-07 4.7105917e-07]
#  [1.2860698e-05 1.3600040e-05 1.9766054e-05 ... 8.1700784e-07
#   6.6302073e-07 9.6155895e-07]]
# test: %s [[9.12315045e-06 1.36561475e-05 1.28317988e-05 ... 1.31561694e-06
#   1.88253500e-06 3.55532109e-07]
#  [9.68985296e-06 1.10363299e-05 1.17873669e-05 ... 9.67869937e-07
#   6.37402536e-07 8.64302763e-07]
#  [4.58592649e-06 1.31443303e-05 4.58397735e-05 ... 5.27786256e-07
#   7.45363025e-07 3.00167358e-07]
#  ...
#  [1.66734808e-05 3.84007508e-05 1.45951080e-05 ... 7.68478742e-07
#   1.13163526e-06 1.08088955e-06]
#  [1.62138767e-05 2.84640701e-05 3.14285789e-05 ... 1.22219163e-07
#   1.27733472e-07 2.25666255e-07]
#  [3.54205235e-06 5.87464774e-06 1.07878577e-05 ... 3.68524252e-06
#   7.30184752e-07 1.33459343e-06]]

# %%
#Création du modèle
def create_model():
  # 2 inputs
  # 2 hidden nodes
  # 1 output

  mlp = keras.Sequential([
      layers.Input(shape=(25,)),
      layers.Dense(32, activation="relu"), # Try different numbers of hidden neurons here (e.g. 2, 4, 8, 32, 128)
      layers.Dense(8, activation="relu"),
  ])

  # Experiment with hyperparameters here:
  # momentum: [0, 0.8, 0.9, 0.99]
  # learning_rate: [0.1, 0.01, 0.001, 0.0001]
  mlp.compile(
      optimizer=keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),
      loss="mse",
  )

  return mlp

mlp = create_model()
mlp.summary()

history_list = []
trained_mlp = []

for i, (train_index, test_index) in enumerate(kfold.split(mice_eeg_input)):
  # We need to create a new model everytime otherwise fit will continue previous training
  scaler = StandardScaler()
  mlp = create_model()

  history = mlp.fit(
      #x=mice_eeg_input[train_index], y=mice_eeg_output[train_index],
      x=scaler.fit_transform(mice_eeg_input[train_index]), y=mice_eeg_output[train_index],
      #validation_data=(mice_eeg_input[test_index], mice_eeg_output[test_index]),
      validation_data=(scaler.transform(mice_eeg_input[test_index]), mice_eeg_output[test_index]),
      epochs=100
  )

  history_list.append(history)
  trained_mlp.append(mlp)
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_32 (Dense)                     │ (None, 32)                  │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,096 (4.28 KB)
#  Trainable params: 1,096 (4.28 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.5012 - val_loss: 0.3779
# Epoch 2/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.3653 - val_loss: 0.3008
# Epoch 3/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.2968 - val_loss: 0.2626
# Epoch 4/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.2626 - val_loss: 0.2442
# Epoch 5/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2459 - val_loss: 0.2339
# Epoch 6/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2360 - val_loss: 0.2270
# Epoch 7/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2293 - val_loss: 0.2221
# Epoch 8/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2243 - val_loss: 0.2185
# Epoch 9/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2205 - val_loss: 0.2156
# Epoch 10/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2174 - val_loss: 0.2133
# Epoch 11/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2149 - val_loss: 0.2114
# Epoch 12/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2129 - val_loss: 0.2099
# Epoch 13/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2112 - val_loss: 0.2085
# Epoch 14/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2097 - val_loss: 0.2074
# Epoch 15/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2084 - val_loss: 0.2063
# Epoch 16/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2073 - val_loss: 0.2054
# Epoch 17/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2062 - val_loss: 0.2046
# Epoch 18/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.2053 - val_loss: 0.2039
# Epoch 19/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2044 - val_loss: 0.2032
# Epoch 20/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2036 - val_loss: 0.2025
# Epoch 21/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.2029 - val_loss: 0.2019
# Epoch 22/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.2023 - val_loss: 0.2013
# Epoch 23/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2016 - val_loss: 0.2008
# Epoch 24/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2010 - val_loss: 0.2003
# Epoch 25/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2004 - val_loss: 0.1998
# Epoch 26/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1999 - val_loss: 0.1993
# Epoch 27/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1994 - val_loss: 0.1989
# Epoch 28/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1989 - val_loss: 0.1985
# Epoch 29/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1984 - val_loss: 0.1981
# Epoch 30/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1980 - val_loss: 0.1977
# Epoch 31/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1975 - val_loss: 0.1974
# Epoch 32/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1971 - val_loss: 0.1970
# Epoch 33/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1967 - val_loss: 0.1967
# Epoch 34/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1963 - val_loss: 0.1964
# Epoch 35/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.1960 - val_loss: 0.1961
# Epoch 36/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1956 - val_loss: 0.1958
# Epoch 37/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1953 - val_loss: 0.1956
# Epoch 38/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1950 - val_loss: 0.1953
# Epoch 39/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1946 - val_loss: 0.1951
# Epoch 40/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.1943 - val_loss: 0.1948
# Epoch 41/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.1940 - val_loss: 0.1946
# Epoch 42/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1938 - val_loss: 0.1944
# Epoch 43/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1935 - val_loss: 0.1942
# Epoch 44/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1932 - val_loss: 0.1940
# Epoch 45/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1930 - val_loss: 0.1938
# Epoch 46/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1928 - val_loss: 0.1936
# Epoch 47/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1926 - val_loss: 0.1935
# Epoch 48/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1923 - val_loss: 0.1933
# Epoch 49/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1921 - val_loss: 0.1932
# Epoch 50/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1919 - val_loss: 0.1930
# Epoch 51/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1917 - val_loss: 0.1929
# Epoch 52/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.
100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.2023 - val_loss: 0.2042
# Epoch 20/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.2016 - val_loss: 0.2036
# Epoch 21/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2009 - val_loss: 0.2030
# Epoch 22/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.2003 - val_loss: 0.2024
# Epoch 23/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1998 - val_loss: 0.2019
# Epoch 24/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1992 - val_loss: 0.2013
# Epoch 25/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1987 - val_loss: 0.2008
# Epoch 26/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1982 - val_loss: 0.2003
# Epoch 27/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1977 - val_loss: 0.1999
# Epoch 28/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1972 - val_loss: 0.1994
# Epoch 29/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1968 - val_loss: 0.1990
# Epoch 30/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1963 - val_loss: 0.1986
# Epoch 31/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1959 - val_loss: 0.1982
# Epoch 32/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1955 - val_loss: 0.1978
# Epoch 33/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1951 - val_loss: 0.1975
# Epoch 34/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1948 - val_loss: 0.1971
# Epoch 35/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1944 - val_loss: 0.1968
# Epoch 36/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1941 - val_loss: 0.1965
# Epoch 37/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1938 - val_loss: 0.1963
# Epoch 38/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1935 - val_loss: 0.1960
# Epoch 39/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1932 - val_loss: 0.1957
# Epoch 40/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1929 - val_loss: 0.1955
# Epoch 41/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1926 - val_loss: 0.1952
# Epoch 42/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1923 - val_loss: 0.1950
# Epoch 43/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1920 - val_loss: 0.1948
# Epoch 44/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1918 - val_loss: 0.1945
# Epoch 45/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1915 - val_loss: 0.1943
# Epoch 46/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1912 - val_loss: 0.1941
# Epoch 47/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1910 - val_loss: 0.1939
# Epoch 48/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1907 - val_loss: 0.1937
# Epoch 49/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1904 - val_loss: 0.1935
# Epoch 50/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1902 - val_loss: 0.1933
# Epoch 51/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1900 - val_loss: 0.1932
# Epoch 52/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1898 - val_loss: 0.1930
# Epoch 53/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1896 - val_loss: 0.1929
# Epoch 54/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1894 - val_loss: 0.1927
# Epoch 55/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1891 - val_loss: 0.1926
# Epoch 56/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1889 - val_loss: 0.1925
# Epoch 57/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1888 - val_loss: 0.1924
# Epoch 58/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1886 - val_loss: 0.1922
# Epoch 59/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1884 - val_loss: 0.1921
# Epoch 60/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1882 - val_loss: 0.1920
# Epoch 61/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1880 - val_loss: 0.1918
# Epoch 62/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1878 - val_loss: 0.1917
# Epoch 63/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1877 - val_loss: 0.1916
# Epoch 64/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1875 - val_loss: 0.1915
# Epoch 65/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1873 - val_loss: 0.1914
# Epoch 66/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1872 - val_loss: 0.1913
# Epoch 67/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1870 - val_loss: 0.1912
# Epoch 68/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1869 - val_loss: 0.1912
# Epoch 69/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1867 - val_loss: 0.1911
# Epoch 70/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1866 - val_loss: 0.1910
# Epoch 71/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1864 - val_loss: 0.1909
# Epoch 72/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1863 - val_loss: 0.1909
# Epoch 73/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1861 - val_loss: 0.1908
# Epoch 74/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1860 - val_loss: 0.1907
# Epoch 75/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1859 - val_loss: 0.1907
# Epoch 76/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1857 - val_loss: 0.1906
# Epoch 77/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1856 - val_loss: 0.1906
# Epoch 78/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1855 - val_loss: 0.1905
# Epoch 79/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1854 - val_loss: 0.1905
# Epoch 80/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1853 - val_loss: 0.1904
# Epoch 81/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1852 - val_loss: 0.1904
# Epoch 82/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1850 - val_loss: 0.1904
# Epoch 83/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1849 - val_loss: 0.1903
# Epoch 84/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1848 - val_loss: 0.1903
# Epoch 85/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1847 - val_loss: 0.1903
# Epoch 86/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.
100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1866 - val_loss: 0.1930
# Epoch 54/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1864 - val_loss: 0.1929
# Epoch 55/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1862 - val_loss: 0.1927
# Epoch 56/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1860 - val_loss: 0.1926
# Epoch 57/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.1858 - val_loss: 0.1925
# Epoch 58/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1856 - val_loss: 0.1924
# Epoch 59/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1854 - val_loss: 0.1923
# Epoch 60/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 0.1852 - val_loss: 0.1922
# Epoch 61/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1850 - val_loss: 0.1922
# Epoch 62/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1849 - val_loss: 0.1921
# Epoch 63/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1847 - val_loss: 0.1920
# Epoch 64/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1846 - val_loss: 0.1919
# Epoch 65/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1844 - val_loss: 0.1919
# Epoch 66/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1843 - val_loss: 0.1918
# Epoch 67/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1841 - val_loss: 0.1917
# Epoch 68/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1840 - val_loss: 0.1917
# Epoch 69/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1839 - val_loss: 0.1916
# Epoch 70/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1837 - val_loss: 0.1916
# Epoch 71/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1836 - val_loss: 0.1915
# Epoch 72/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1835 - val_loss: 0.1915
# Epoch 73/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1833 - val_loss: 0.1914
# Epoch 74/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1832 - val_loss: 0.1913
# Epoch 75/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1831 - val_loss: 0.1913
# Epoch 76/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1830 - val_loss: 0.1912
# Epoch 77/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1829 - val_loss: 0.1911
# Epoch 78/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1827 - val_loss: 0.1911
# Epoch 79/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1826 - val_loss: 0.1910
# Epoch 80/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1825 - val_loss: 0.1910
# Epoch 81/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1824 - val_loss: 0.1909
# Epoch 82/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1823 - val_loss: 0.1909
# Epoch 83/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1822 - val_loss: 0.1908
# Epoch 84/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1821 - val_loss: 0.1908
# Epoch 85/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1820 - val_loss: 0.1907
# Epoch 86/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1819 - val_loss: 0.1907
# Epoch 87/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1818 - val_loss: 0.1907
# Epoch 88/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1817 - val_loss: 0.1906
# Epoch 89/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1816 - val_loss: 0.1906
# Epoch 90/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1815 - val_loss: 0.1906
# Epoch 91/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1814 - val_loss: 0.1905
# Epoch 92/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1813 - val_loss: 0.1905
# Epoch 93/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1812 - val_loss: 0.1905
# Epoch 94/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1812 - val_loss: 0.1905
# Epoch 95/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1811 - val_loss: 0.1905
# Epoch 96/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1810 - val_loss: 0.1904
# Epoch 97/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1809 - val_loss: 0.1904
# Epoch 98/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1808 - val_loss: 0.1904
# Epoch 99/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1807 - val_loss: 0.1904
# Epoch 100/100
# 852/852 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1806 - val_loss: 0.1904

# %%
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns

#Plot

train_losses = np.array([history.history['loss'] for history in history_list])
val_losses = np.array([history.history['val_loss'] for history in history_list])

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.mean(train_losses, axis=0)
std_train_loss = np.std(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)
std_val_loss = np.std(val_losses, axis=0)

# Plot mean and standard deviation for training loss
pl.plot(mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(range(len(mean_train_loss)), mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(range(len(mean_val_loss)), mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

#Confusion Matrix

def plot_confusion_matrix(confusion_matrix, title):
    # Plot confusion matrix
    pl.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=True, fmt="d", cmap="Blues", cbar=False,
                xticklabels=["Awake", "Non-REM", "REM"], yticklabels=["Awake", "Non-REM", "REM"])

    pl.title(title)
    pl.xlabel('Predicted')
    pl.ylabel('True')
    pl.show()

f1_scores = []
mean_confusion_matrix = np.zeros((3, 3))

for i, (train_index, test_index) in enumerate(kfold.split(mice_eeg_input)):
    # Evaluate the trained model on the test fold
    predictions = trained_mlp[i].predict(scaler.transform(mice_eeg_input[test_index]))
    #true_labels = (mice_eeg_output[test_index] > 0).astype(int)
    predicted_labels = np.round(predictions).astype(int)[:, 0]
    true_labels = mice_eeg_output[test_index].astype(int)[:, 0]

    # Compute confusion matrix
    #cm = confusion_matrix(true_labels, predictions[::, 0], labels=[0, 1, 2])
    cm = confusion_matrix(true_labels, predicted_labels, labels=[0, 1, 2])
    #mean_confusion_matrix += confusion_matrix(true_labels, predictions[::, 0])
    mean_confusion_matrix += cm

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}')

    # Compute F1 score
    #f1 = f1_score(true_labels, predictions[::, 0])
    f1 = f1_score(true_labels, predicted_labels, average='weighted')
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix, 'Global confusion matrix')

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# F1 Score - Fold 1: 0.8253341928537866
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# F1 Score - Fold 2: 0.8296356442464352
# 426/426 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# F1 Score - Fold 3: 0.8220403547430408
# Mean F1 Score across all folds: 0.8256700639477543

# %%
mice_eeg_test = pd.read_csv('EEG_mouse_data_test.csv')
mice_eeg_test = np.array(mice_eeg)

eeg_test_input = mice_eeg_test[:, 1:26].astype('float32')
eeg_test_output = mice_eeg_test[:, 0:1]

# Transformer les labels comme dans le training
eeg_test_output[eeg_test_output == 'w'] = 0
eeg_test_output[eeg_test_output == 'n'] = 1
eeg_test_output[eeg_test_output == 'r'] = 2
eeg_test_output = eeg_test_output.astype('float32')

scaler_final = StandardScaler()
scaler_final.fit(mice_eeg_input)  # Fit sur toutes les données d'entraînement

eeg_test_input_scaled = scaler_final.transform(eeg_test_input)

# Utiliser le dernier modèle entraîné (ou faire une moyenne des 3 modèles si tu veux, mais ici on va simple)
model_to_use = trained_mlp[-1]  # dernier modèle entraîné

# Prédictions
predictions_test = model_to_use.predict(eeg_test_input_scaled)
predicted_labels_test = np.round(predictions_test).astype(int)[:, 0]
true_labels_test = eeg_test_output.astype(int)[:, 0]

# Confusion matrix
cm_test = confusion_matrix(true_labels_test, predicted_labels_test, labels=[0, 1, 2])
plot_confusion_matrix(cm_test, 'Confusion Matrix - Test Set')

# F1 score
f1_test = f1_score(true_labels_test, predicted_labels_test, average='weighted')
print(f"F1 Score on test set: {f1_test}")
# Out:
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# F1 Score on test set: 0.8251050209911578
